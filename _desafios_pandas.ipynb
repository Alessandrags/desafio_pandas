# %% [markdown]
# <a href="https://colab.research.google.com/github/Alessandrags/desafio_pandas/blob/main/_desafios_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Descrição
#
# Esse notebook foi construído para realizar os desafios propostos no final de cada aula do curso **Pandas: conhecendo a biblioteca**

# %% [markdown]
# ## Aula 1: Conhecendo a base de dados

# %% [markdown]
# ### Desafio 1
# Importe o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) e armazene seu conteúdo em um DataFrame Pandas

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'

# %%
df_alunos = pd.read_csv(url)

# %% [markdown]
# ### Desafio 2
# Visualize as primeiras 7 linhas do DataFrame e as 5 últimas

# %%
df_alunos.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
df_alunos.tail()
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 3
# Confira a quantidade de linhas e colunas do DataFrame

# %%
df_alunos.shape
# Out:
# (18, 4)

# %% [markdown]
# ### Desafio 4
# Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna

# %%
df_alunos.columns
# Out:
# Index(['Nome', 'Idade', 'Notas', 'Aprovado'], dtype='object')

# %%
df_alunos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes

# %%
df_alunos['Nome']
# Out:
# 0           Ary
# 1           Ana
# 2         Cátia
# 3         Denis
# 4          Beto
# 5         Bruna
# 6          Dara
# 7        Carlos
# 8         Alice
# 9         Vitor
# 10       Daniel
# 11         Igor
# 12    Sthefanie
# 13        Mirla
# 14        Paulo
# 15       Mylena
# 16        Lucas
# 17        Nadia
# Name: Nome, dtype: object

# %%
df_alunos[['Idade', 'Notas']]
# Out:
#     Idade  Notas
# 0      20    7.5
# 1      18    NaN
# 2      27    2.5
# 3      18    5.0
# 4      21   10.0
# 5      23    NaN
# 6      21    7.0
# 7      19    6.0
# 8      35    5.6
# 9      28    NaN
# 10     21    NaN
# 11     24    4.5
# 12     26    9.5
# 13     25    9.0
# 14     37    NaN
# 15     29    7.0
# 16     33    NaN
# 17     34    8.0

# %%
df_alunos['Aprovado']
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# 16    False
# 17     True
# Name: Aprovado, dtype: bool

# %%
#Veerifica o tipo de dados de cada coluna

df_alunos.dtypes
# Out:
# Nome         object
# Idade         int64
# Notas       float64
# Aprovado       bool
# dtype: object

# %% [markdown]
# ### **Extra**
# Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc) - Dica: pesquise pelo método **describe**

# %%
df_alunos.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# ## Aula 2: Análise exploratória dos dados

# %% [markdown]
# Para os desafios dessa aula, vamos utilizar a mesma base de dados que estamos utilizando para o desenvolvimento do nosso projeto. Sendo assim, na célula abaixo vamos realizar a importação dessa base de dados e aplicar as transformações já realizadas até o momento da aula 2.

# %%
import pandas as pd

# %%
# importando a base de dados
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# removendo imóveis comerciais
df = dados.query('@imoveis_comerciais not in Tipo')

# selecionando apenas imóveis do tipo apartamento
df = df.query('Tipo == "Apartamento"')

# visualizando a base de dados
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# ### Desafio 1
# Calcular a média de quartos por apartamento

# %%
df['Quartos'].mean()
# Out:
# np.float64(2.481568707761622)

# %% [markdown]
# ### Desafio 2
# Conferir quantos bairros únicos existem na nossa base de dados

# %%
df.Bairro.unique()
# Out:
# array(['Centro', 'Higienópolis', 'Vista Alegre', 'Cachambi', 'Grajaú',
#        'Lins de Vasconcelos', 'Copacabana', 'Freguesia (Jacarepaguá)',
#        'Barra da Tijuca', 'Tijuca', 'Olaria', 'Ipanema', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'Jardim Botânico', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
#        'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
#        'Praça Seca', 'Lagoa', 'Catete', 'Jardim Carioca', 'Vila Isabel',
#        'Rocha Miranda', 'Taquara', 'Engenho Novo', 'Campo Grande',
#        'Flamengo', 'Engenho de Dentro', 'São Conrado', 'Cidade Nova',
#        'Pilares', 'Tomás Coelho', 'Água Santa', 'São Cristóvão',
#        'Ilha do Governador', 'Vila da Penha', 'Anil', 'Vaz Lobo',
#        'Madureira', 'São Francisco Xavier', 'Pechincha', 'Leme', 'Irajá',
# ...

# %%
## Função len, conta quantos elementos existem na lista.

len(df.Bairro.unique())
# Out:
# 149

# %%
## metódo nunique() que faz a contagem de elementos únicos no Pandas

df.Bairro.nunique()
# Out:
# 149

# %%
df.Bairro.value_counts()
# Out:
# Bairro
# Barra da Tijuca             3341
# Copacabana                  2465
# Ipanema                     1768
# Recreio dos Bandeirantes    1490
# Leblon                      1241
#                             ...
# Parque Anchieta                1
# Caju                           1
# Cidade Jardim                  1
# Coelho Neto                    1
# Grumari                        1
# Name: count, Length: 149, dtype: int64

# %% [markdown]
# ### Desafio 3
# Analisar quais bairros possuem a média de valor de aluguel mais elevadas

# %%
## o parâmetro ascending=False é usado na função sort_values() para ordenard os valores em ordem decrescente(do maior para o menor).

df.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False)
# Out:
#                                Valor
# Bairro
# Joá                     15500.000000
# Arpoador                12429.769231
# Cidade Jardim           12000.000000
# Ipanema                  9487.205317
# Botafogo                 9369.207116
# ...                              ...
# Inhoaíba                  650.000000
# Cosmos                    610.000000
# Santa Cruz                590.000000
# Paciência                 510.000000
# Ricardo de Albuquerque    340.000000
#
# [149 rows x 1 columns]

# %% [markdown]
# ### Desafio 4
# Criar um gráfico de barras verticais que apresente os 5 bairros com a média de valor de aluguel mais elevadas

# %%
df_bairros = df.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False).head()
df_bairros
# Out:
#                       Valor
# Bairro
# Joá            15500.000000
# Arpoador       12429.769231
# Cidade Jardim  12000.000000
# Ipanema         9487.205317
# Botafogo        9369.207116

# %%
df_bairros.head(5)
# Out:
#                       Valor
# Bairro
# Joá            15500.000000
# Arpoador       12429.769231
# Cidade Jardim  12000.000000
# Ipanema         9487.205317
# Botafogo        9369.207116

# %%
df_bairros.head(5).plot(kind='barh', figsize=(14,10), color='green')
# Out:
# <Axes: ylabel='Bairro'>

# %% [markdown]
# ## Aula 3
#
# Importe novamente o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) para realizar os desafios abaixo.

# %%
# Importando novamente os dados

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df_alunos = pd.read_csv(url)
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 1
# Verifique se a base de dados possui dados nulos e caso tenha, realize o tratamento desses dados nulos

# %%
df_alunos.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
df_alunos.fillna(0, inplace=True)

# %%
df_alunos.isnull().sum()
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %% [markdown]
# ### Desafio 2
# Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados

# %%
df_alunos.drop([7,8], inplace=True)

# %%
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# Outra forma de resolver.
#
#
#
# ```
# # salvando os índices das linhas a serem removidas em uma variável
#
# alunos_a_remover = dados.query('Nome == "Alice" | Nome == "Carlos"').index
#
# # removendo as linhas referentes aos alunos "Alice" e "Carlos"
#
# dados.drop(alunos_a_remover, axis=0, inplace=True)
#
# ```

# %% [markdown]
# ### Desafio 3
# Aplique um filtro que selecione apenas os alunos que foram aprovados

# %%
aprovados = df_alunos.query('Aprovado == True')
aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 4
# Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv"

# %%
aprovados.to_csv('alunos_aprovados.csv')

# %%
pd.read_csv('alunos_aprovados.csv', sep=';')
# Out:
#   ,Nome,Idade,Notas,Aprovado
# 0          0,Ary,20,7.5,True
# 1        4,Beto,21,10.0,True
# 2         6,Dara,21,7.0,True
# 3   12,Sthefanie,26,9.5,True
# 4       13,Mirla,25,9.0,True
# 5      15,Mylena,29,7.0,True
# 6       17,Nadia,34,8.0,True

# %%
aprovados.to_csv('alunos_aprovados.csv', index=False, sep=';')

# %%
pd.read_csv('alunos_aprovados.csv', sep=';')
# Out:
#         Nome  Idade  Notas  Aprovado
# 0        Ary     20    7.5      True
# 1       Beto     21   10.0      True
# 2       Dara     21    8.0      True
# 3  Sthefanie     26    9.5      True
# 4      Mirla     25    9.0      True
# 5     Mylena     29    8.0      True
# 6      Nadia     34    8.0      True

# %% [markdown]
# ### **Extra**
# Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. **Dica**: pesquise pelo método **replace**

# %%
aprovados.replace(7.0, 8.0, inplace=True)
# Out:
# <ipython-input-129-3b1ff73ac71a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aprovados.replace(7.0, 8.0, inplace=True)

# %%
aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# ## Aula 4
#
# Importe novamente o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) para realizar os desafios abaixo.

# %%
# Importando novamente os dados
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df_alunos = pd.read_csv(url)
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %%
df_alunos.isnull().sum()
# Out:
# Nome             0
# Idade            0
# Notas            6
# Aprovado         0
# Pontos_extras    6
# Notas_finais     6
# dtype: int64

# %%
df_alunos.fillna(0, inplace=True)

# %%
df_alunos.isnull().sum()
# Out:
# Nome             0
# Idade            0
# Notas            0
# Aprovado         0
# Pontos_extras    0
# Notas_finais     0
# dtype: int64

# %% [markdown]
# ### Desafio 1
# Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles

# %%
pontos_extras = df_alunos['Notas'] * 0.4
pontos_extras

df_alunos['Pontos_extras'] = pontos_extras
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 0    Ary     20    7.5      True            3.0          10.5       Aprovado
# 1    Ana     18    0.0     False            0.0           0.0      Reprovado
# 2  Cátia     27    2.5     False            1.0           3.5      Reprovado
# 3  Denis     18    5.0     False            2.0           7.0       Aprovado
# 4   Beto     21   10.0      True            4.0          14.0       Aprovado

# %%
df_alunos['Pontos_extras'] = df_alunos['Notas'].apply(lambda x: x*0.4)
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 0    Ary     20    7.5      True            3.0          10.5       Aprovado
# 1    Ana     18    0.0     False            0.0           0.0      Reprovado
# 2  Cátia     27    2.5     False            1.0           3.5      Reprovado
# 3  Denis     18    5.0     False            2.0           7.0       Aprovado
# 4   Beto     21   10.0      True            4.0          14.0       Aprovado

# %% [markdown]
# ### Desafio 2
# Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras

# %%
df_alunos['Notas_finais'] = df_alunos['Notas'] + df_alunos['Pontos_extras']
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 0    Ary     20    7.5      True            3.0          10.5       Aprovado
# 1    Ana     18    0.0     False            0.0           0.0      Reprovado
# 2  Cátia     27    2.5     False            1.0           3.5      Reprovado
# 3  Denis     18    5.0     False            2.0           7.0       Aprovado
# 4   Beto     21   10.0      True            4.0          14.0       Aprovado

# %% [markdown]
# ### Desafio 3
# Como os alunos ganharam pontos extras, alguns que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# * True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# * False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
df_alunos['Aprovado_final'] = (df_alunos['Notas_finais'] >= 6).apply(lambda x: 'Aprovado' if x else 'Reprovado')
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 0    Ary     20    7.5      True            3.0          10.5       Aprovado
# 1    Ana     18    0.0     False            0.0           0.0      Reprovado
# 2  Cátia     27    2.5     False            1.0           3.5      Reprovado
# 3  Denis     18    5.0     False            2.0           7.0       Aprovado
# 4   Beto     21   10.0      True            4.0          14.0       Aprovado

# %%
df_alunos['Aprovado_final'] = df_alunos['Notas_finais'].apply(lambda x: True if x >= 6 else False)
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  Aprovado_final
# 0    Ary     20    7.5      True            3.0          10.5            True
# 1    Ana     18    0.0     False            0.0           0.0           False
# 2  Cátia     27    2.5     False            1.0           3.5           False
# 3  Denis     18    5.0     False            2.0           7.0            True
# 4   Beto     21   10.0      True            4.0          14.0            True

# %% [markdown]
# ### Desafio 4
# Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras

# %%
antes_do_extra = df_alunos.query('Aprovado == False')
antes_do_extra

aprovados_depois_do_extra = antes_do_extra.query('Aprovado_final == "Aprovado"')
aprovados_depois_do_extra
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 3   Denis     18    5.0     False           2.00          7.00       Aprovado
# 8   Alice     35    5.6     False           2.24          7.84       Aprovado
# 11   Igor     24    4.5     False           1.80          6.30       Aprovado

# %%
#outra forma para obter o mesmo resultado

selecao = (df_alunos['Aprovado'] == False) & (df_alunos['Aprovado_final'] == "Aprovado")
df_alunos[selecao]
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 3   Denis     18    5.0     False           2.00          7.00       Aprovado
# 8   Alice     35    5.6     False           2.24          7.84       Aprovado
# 11   Igor     24    4.5     False           1.80          6.30       Aprovado

# %%
#outra forma para obter o mesmo resultado

df_alunos.query('Aprovado == False & Aprovado_final == "Aprovado"')
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 3   Denis     18    5.0     False           2.00          7.00       Aprovado
# 8   Alice     35    5.6     False           2.24          7.84       Aprovado
# 11   Igor     24    4.5     False           1.80          6.30       Aprovado
